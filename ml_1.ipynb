# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/fake_reg.csv')

# %%
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130011   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720992  1001.451646   998.847606
# 998  403.315576  1000.771023   998.562851
# 999  599.367093   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values

# %%
y = df['price'].values

# %%
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
y
# Out:
# array([461.52792939, 548.13001146, 410.29716167, 540.38221981,
#        546.02455292, 542.9836716 , 555.48566416, 417.56972453,
#        373.14653122, 633.35029248, 624.24709206, 475.37241721,
#        600.36844486, 532.83295175, 472.8353628 , 506.31229096,
#        508.414406  , 610.4553519 , 323.65776198, 446.21230389,
#        362.12270299, 433.41064026, 562.00257647, 637.30962074,
#        522.80800754, 469.8028243 , 543.10992778, 565.43416994,
#        530.03285381, 610.58016503, 482.55641188, 327.56004052,
#        579.73083872, 448.42981468, 628.97709187, 536.79737216,
#        570.06729543, 357.82557519, 612.08492732, 444.67970846,
#        600.1186364 , 523.53312776, 512.94994495, 614.8813169 ,
#        404.35303251, 643.68851807, 488.95660398, 443.20468572,
#        514.47906638, 514.88174058, 325.05852217, 554.6620585 ,
#        451.39140001, 587.67887726, 477.73749721, 574.51560687,
#        548.9107991 , 528.69088356, 443.21100482, 397.88209319,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_test.shape
# Out:
# (300, 2)

# %%
y_train.shape
# Out:
# (700,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.74046017, 0.32583248],
#        [0.43166001, 0.2555088 ],
#        [0.18468554, 0.70500664],
#        ...,
#        [0.54913363, 0.79933822],
#        [0.2834197 , 0.38818708],
#        [0.56282703, 0.42371827]])

# %%
X_test
# Out:
# array([[ 0.39533339,  0.38540671],
#        [ 0.57300502,  0.74070924],
#        [ 0.61294076,  0.65734264],
#        [ 0.38169528,  0.73076311],
#        [ 0.07776591,  0.46323644],
#        [ 0.49421971,  0.68949258],
#        [ 0.2065742 ,  0.70096247],
#        [ 0.55141988,  0.41776773],
#        [ 0.36812191,  0.69082394],
#        [ 0.56465724,  0.3877465 ],
#        [ 0.57048029,  0.71810824],
#        [ 0.79569525,  0.47979901],
#        [ 0.38488235,  0.41856516],
#        [ 0.33142545,  0.42411972],
#        [ 0.89361377,  0.63912775],
#        [ 0.50191166,  0.39789174],
#        [ 0.7159808 ,  0.43688384],
#        [ 0.35812192,  0.92028225],
#        [ 0.49989367,  0.85589311],
#        [ 0.63965434,  0.59024789],
#        [ 0.19053626,  0.34203634],
#        [ 0.40982896,  0.45849208],
#        [ 0.26844791,  0.40167269],
#        [ 0.38649709,  0.33592759],
#        [ 0.50654703,  0.65789843],
#        [ 0.41260556,  0.79338075],
#        [ 0.45631316,  0.61323307],
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(4, activation = 'relu'))
model.add(Dense(4, activation = 'relu'))
model.add(Dense(4, activation = 'relu'))
#model.add(Dense(4, activation = 'relu'))
model.add(Dense(1))


model.compile(optimizer='rmsprop', loss='mse')

# %%
model.fit(x= X_train, y = y_train, epochs= 500)
# Out:
# Epoch 1/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1245.3350
# Epoch 2/500
# 22/22 [==============================] - 0s 3ms/step - loss: 1226.2421
# Epoch 3/500
# 22/22 [==============================] - 0s 3ms/step - loss: 1206.9159
# Epoch 4/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1189.5201
# Epoch 5/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1171.6067
# Epoch 6/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1151.4648
# Epoch 7/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1132.8243
# Epoch 8/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1113.4384
# Epoch 9/500
# 22/22 [==============================] - 0s 3ms/step - loss: 1092.1375
# Epoch 10/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1070.8984
# Epoch 11/500
# 22/22 [==============================] - 0s 2ms/step - loss: 1051.7609
# Epoch 12/500
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df
# Out:
#             loss
# 0    1245.334961
# 1    1226.242065
# 2    1206.915894
# 3    1189.520142
# 4    1171.606689
# ..           ...
# 495    24.247883
# 496    24.188328
# 497    24.124241
# 498    23.862679
# 499    23.989443
#
# [500 rows x 1 columns]

# %%
loss_df.plot()
# Out:
# <Axes: >

# %%
model.evaluate(X_test, y_test, verbose = 0)
# Out:
# 24.937973022460938

# %%
model.evaluate(X_train, y_train, verbose = 0)
# Out:
# 24.06873893737793

# %%
test_predicts = model.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
test_predicts
# Out:
# array([[405.02188],
#        [623.28534],
#        [591.881  ],
#        [571.95624],
#        [366.32245],
#        [578.9188 ],
#        [514.76843],
#        [458.85263],
#        [548.97424],
#        [447.26602],
#        [611.5315 ],
#        [548.7106 ],
#        [418.8312 ],
#        [408.59665],
#        [651.01434],
#        [437.04025],
#        [508.2108 ],
#        [659.6593 ],
#        [662.32306],
#        [565.2893 ],
#        [333.94324],
#        [444.5672 ],
#        [382.24826],
#        [378.4867 ],
#        [566.33594],
#        [610.3248 ],
#        [532.12756],
#        [427.59628],
#        [655.1781 ],
#        [413.8238 ],
#        [442.38016],
#        [484.86536],
#        [438.15067],
#        [681.58716],
#        [424.5071 ],
#        [417.40927],
#        [501.69144],
#        [550.2189 ],
#        [509.45407],
#        [395.06625],
#        [618.3423 ],
#        [416.36853],
#        [604.1987 ],
#        [445.71194],
#        [501.7272 ],
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#check missing data
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#statistical
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
#data visualization
plt.figure(figsize=(10,6))
sns.distplot(df['price'])
#graph shows above 3 are considered as a outliners
# Out:
# <ipython-input-13-2f66b55f1d90>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#no of badrooms
sns.countplot(x = df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()  #price with price highly correlate with each other, likewise shift_living
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data = df, x = 'price', y = 'sqft_living')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
 plt.figure(figsize = (10,5))
 sns.boxplot(x='bedrooms', y= 'price', data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize= (10,5))
sns.scatterplot(x="long", y="lat", data = df, hue= 'price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7245  2014-10-13  7700000.0         6       8.00        12050     27600
# 3910  2014-06-11  7060000.0         5       4.50        10040     37325
# 9245  2014-09-19  6890000.0         6       7.75         9890     31374
# 4407  2014-08-04  5570000.0         5       5.75         9200     35069
# 1446  2015-04-13  5350000.0         5       5.00         8000     23985
# 1313  2015-04-13  5300000.0         6       6.00         7390     24829
# 1162  2014-10-20  5110000.0         5       5.25         8010     45517
# 8085  2014-06-17  4670000.0         5       6.75         9640     13068
# 2624  2014-08-15  4500000.0         5       5.50         6640     40014
# 8629  2014-06-18  4490000.0         4       3.00         6430     27517
# 12358 2015-05-06  4210000.0         5       6.00         7440     21540
# 4145  2014-10-14  4000000.0         4       5.50         7080     16573
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_1_per_house = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize= (10,5))
sns.scatterplot(x="long", y="lat", data =non_1_per_house , hue= 'price', edgecolor = None, alpha = 0.2, palette= "RdYlGn")
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize= (10,5))
sns.boxplot(x="waterfront", y="price", data = df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# Feature Engineering: the pre-processing step of machine learning, which extracts features from raw data.

# %%
df= df.drop('id', axis = 1)

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df["date"]
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
#lamba expression
def year_extration(date):
  return date.year

# %%
df['year']= df['date'].apply(lambda date: date.year)

# %%
df['year']
# Out:
# 0        2014
# 1        2014
# 2        2015
# 3        2014
# 4        2015
#          ...
# 21592    2014
# 21593    2015
# 21594    2014
# 21595    2015
# 21596    2014
# Name: year, Length: 21597, dtype: int64

# %%
df['month']= df['date'].apply(lambda date: date.month)

# %%
df['month']
# Out:
# 0        10
# 1        12
# 2         2
# 3        12
# 4         2
#          ..
# 21592     5
# 21593     2
# 21594     6
# 21595     1
# 21596    10
# Name: month, Length: 21597, dtype: int64

# %%
df.head() # shows newly added year and month coloumn
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month', y='price', data = df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df= df.drop('date', axis= 1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df= df.drop('zipcode', axis = 1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price', axis = 1).values # values will return numepy array
y = df['price'].values

# %%
X
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 5.650e+03, 2.014e+03,
#         1.000e+01],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 7.639e+03, 2.014e+03,
#         1.200e+01],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 8.062e+03, 2.015e+03,
#         2.000e+00],
#        ...,
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 2.007e+03, 2.014e+03,
#         6.000e+00],
#        [3.000e+00, 2.500e+00, 1.600e+03, ..., 1.287e+03, 2.015e+03,
#         1.000e+00],
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 1.357e+03, 2.014e+03,
#         1.000e+01]])

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %% [markdown]
# 19 incomming features so 19 neurons in our layers

# %%
model = Sequential()
model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))
model.add(Dense(19, activation = "relu"))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.fit(x= X_train, y= y_train, 
          validation_data= (X_test, y_test),
          batch_size = 128,
          epochs= 400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 5ms/step - loss: 429753106432.0000 - val_loss: 420125310976.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 429215449088.0000 - val_loss: 418080587776.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 419988996096.0000 - val_loss: 396185698304.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 371259998208.0000 - val_loss: 313927270400.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 250801733632.0000 - val_loss: 170923507712.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 129923809280.0000 - val_loss: 102300164096.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 100236926976.0000 - val_loss: 97898930176.0000
# Epoch 8/400
# ...

# %%
losses= pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
prediction = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step

# %%
np.sqrt(mean_squared_error(y_test,prediction))
# Out:
# 175908.43507373394
